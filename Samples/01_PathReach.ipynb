# %% [markdown]
# # SNAPy PathReach
# 24/09/2024
#
# Showcasing PathReach capabilities

# %% [markdown]
# #### 1. Initializing GraphSim class
# Similar to introduction notebook, we load graphsims. Note that in this notebook, the loaded network information uses segmented edges.

# %%
import SNAPy as sna
import geopandas as gpd

MainDir = 'https://raw.githubusercontent.com/kevinsutjijadi/SNAPyDocs/main/Samples/SampleData/'
dfNetwork = gpd.read_file(MainDir+'CentralJakarta_Roadline_Segmented.gpkg')
dfEntries = gpd.read_file(MainDir+'CentralJakarta_Entries.gpkg')

nwSim = sna.GraphSims(dfNetwork, dfEntries)
# Out:
# GraphSim Class ----------
# Projection EPSG:32748
# EntriesDf EntID not detected, adding from index
# NetworkDf EdgeID not detected, adding from index
# Graph Built with 7,823 Nodes, 10,075 Edges
# Graph mapped 40,705 Entries
# Detected 2 Entries unable to map to network. Coordinate error or further than EntDist parameter
# 	Entry ids are :
# 	[3841, 27441]
# Graph initialization finished in 2.0185 s

# %% [markdown]
# #### 2. Simple PathReach
# from one point, reffering to the entry id, pathreach calculates the reach in the network.

# %%
OriginId = [19287,] # if returns error, please use list on origin ID, not tuple
rslt = nwSim.PathReach(OriginId, distance=400, showmap=True)
rslt[0] # first index to show map.
# Out:
# if showmap, incl_nodes must be true
# to see map, please set/access index 0 of result
# {
#   "initialViewState": {
#     "latitude": -6.184588108600299,
#     "longitude": 106.82649013011793,
#     "zoom": 15
#   },
#   "layers": [
#     {
#       "@@type": "GeoJsonLayer",
#       "data": [
#         {
#           "Oid": 19287,
#           "fid": 5866,
#           "geometry": {
#             "coordinates": [
#               [
#                 106.8269171,
#                 -6.184537100000006
#               ],
#               [
#                 106.8268414,
#                 -6.184508599999994
#               ],
#               [
#                 106.8266616,
#                 -6.184464000000006
#               ],
#               [
#                 106.826386,
#                 -6.184404900000001
#               ],
#               [
#                 106.826386,
#                 -6.184404900000001
#               ]
#             ],
#             "type": "LineString"
#           },
#           "vector": 1.0
#         },
#         {
#           "Oid": 19287,
#           "fid": 2633,
#           "geometry": {
#             "coordinates": [
#               [
#                 106.826386,
#                 -6.184404900000001
#               ],
#               [
#                 106.8264145,
#                 -6.184248299999992
#               ],
#               [
#                 106.8264458,
#                 -6.184134100000002
#               ],
#               [
#                 106.8264612,
#                 -6.184077600000004
#               ],
#               [
#                 106.826483,
#                 -6.1839980999999975
#               ],
#               [
#                 106.8265259,
#                 -6.183870799999991
#               ],
#               [
#                 106.8265298,
#                 -6.1838653
#               ],
#               [
#                 106.8265376,
#                 -6.183864800000004
#               ],
#               [
#                 106.8265445,
#                 -6.183865800000001
#               ],
#               [
#                 106.8266901,
#                 -6.183895199999995
#               ],
#               [
#                 106.8266964,
#                 -6.183899200000004
#               ],
#               [
#                 106.8267001,
#                 -6.183907200000007
#               ],
#               [
#                 106.8266956,
#                 -6.183948200000007
#               ],
#               [
#                 106.8266981,
#                 -6.183953200000007
#               ],
#               [
#                 106.826706,
#                 -6.183958800000004
#               ],
#               [
#                 106.8268042,
#                 -6.183984600000005
#               ],
#               [
#                 106.82680840000002,
#                 -6.183987200000001
#               ],
#               [
#                 106.8268113,
#                 -6.183991699999996
#               ],
#               [
#                 106.8268123,
#                 -6.183999199999999
#               ],
#               [
#                 106.8268003,
#                 -6.184060400000007
#               ],
#               [
#                 106.8267811,
#                 -6.184124800000005
#               ],
#               [
#                 106.8267804,
#                 -6.184132199999992
#               ],
#               [
#                 106.8267837,
#                 -6.1841389999999965
#               ]
#             ],
#             "type": "LineString"
#           },
#           "vector": 1.0
#         },
#         {
#           "Oid": 19287,
#           "fid": 5867,
#           "geometry": {
#             "coordinates": [
#               [
#                 106.826386,
#                 -6.184404900000001
#               ],
#               [
#                 106.8259563,
#                 -6.184286000000007
#               ]
#             ],
#             "type": "LineString"
#           },
#           "vector": 1.0
#         },
#         {
#           "Oid": 19287,
#           "fid": 2630,
#           "geometry": {
#             "coordinates": [
#               [
#                 106.8269171,
#                 -6.184537100000006
#               ],
#               [
#                 106.8269751,
#                 -6.184309999999998
#               ],
#               [
#                 106.8269887,
#                 -6.184238200000005
#               ],
#               [
#                 106.8269984,
#                 -6.184195300000002
#               ],
#               [
#                 106.8269984,
#                 -6.184195300000002
#               ]
#             ],
#             "type": "LineString"
#           },
#           "vector": 1.0
#         },
#         {
#           "Oid": 19287,
#           "fid": 5865,
#           "geometry": {
#             "coordinates": [
#               [
#                 106.82708770000002,
#                 -6.184658200000006
#               ],
#               [
#                 106.8270552,
#                 -6.184620500000002
#               ],
#               [
#                 106.8270153,
#                 -6.184574199999995
#               ],
#               [
#                 106.8269171,
#                 -6.184537100000006
#               ],
#               [
#                 106.8269171,
#                 -6.184537100000006
#               ]
#             ],
#             "type": "LineString"
#           },
#           "vector": -1.0
#         },
#         {
#           "Oid": 19287,
#           "fid": 2779,
#           "geometry": {
#             "coordinates": [
#               [
#                 106.8258702,
#                 -6.184530999999996
#               ],
#               [
#                 106.825868,
#                 -6.184507799999993
#               ],
#               [
#                 106.8258728,
#                 -6.184452299999997
#               ],
#               [
#                 106.82588090000002,
#                 -6.184417199999995
#               ],
#               [
#                 106.8258956,
#                 -6.184383699999993
#               ],
#               [
#                 106.8259563,
#                 -6.184286000000007
#               ]
#             ],
#             "type": "LineString"
#           },
#           "vector": -1.0
#         },
#         {
#           "Oid": 19287,
#           "fid": 9469,
#           "geometry": {
#             "coordinates": [
#               [
#                 106.8259563,
#                 -6.184286000000007
#               ],
#               [
#                 106.8259283,
#                 -6.184246399999999
#               ],
#               [
#                 106.8259035,
#                 -6.184161100000001
#               ],
#               [
#                 106.82588410000001,
#                 -6.184076000000001
#               ],
#               [
#                 106.82585920000001,
#                 -6.183998199999994
#               ],
#               [
#                 106.8258386,
#                 -6.183936800000003
#               ],
#               [
#                 106.8258386,
#                 -6.183936800000003
#               ]
#             ],
#             "type": "LineString"
#           },
#           "vector": 1.0
#         },
#         {
#           "Oid": 19287,
#           "fid": 2642,
#           "geometry": {
#             "coordinates": [
#               [
#                 106.82708770000002,
#                 -6.184658200000006
#               ],
#               [
#                 106.8269355,
#                 -6.1850687999999945
#               ]
#             ],
#             "type": "LineString"
#           },
#           "vector": 1.0
#         },
#         {
#           "Oid": 19287,
#           "fid": 5864,
#           "geometry": {
#             "coordinates": [
#               [
#                 106.8273633,
#                 -6.184783700000008
#               ],
#               [
#                 106.8272419,
#                 -6.184740799999995
#               ],
#               [
#                 106.8271735,
#                 -6.184710099999996
#               ],
#               [
#                 106.82708770000002,
#                 -6.184658200000006
#               ],
#               [
#                 106.82708770000002,
#                 -6.184658200000006
#               ]
#             ],
#             "type": "LineString"
#           },
#           "vector": -1.0
#         },
#         {
#           "Oid": 19287,
#           "fid": 2631,
#           "geometry": {
#             "coordinates": [
#               [
#                 106.8269984,
#                 -6.184195300000002
#               ],
#               [
#                 106.8270431,
#                 -6.184192699999999
#               ],
#               [
#                 106.8270743,
#                 -6.184062799999996
#               ],
#               [
#                 106.8270743,
#                 -6.184062799999996
#               ]
#             ],
#             "type": "LineString"
#           },
#           "vector": 1.0
#         },
#         {
#           "Oid": 19287,
#           "fid": 2781,
#           "geometry": {
#             "coordinates": [
#               [
#                 106.8267837,
#                 -6.1841389999999965
#               ],
#               [
#                 106.8267917,
#                 -6.184143300000008
#               ],
#               [
#                 106.8269984,
#                 -6.184195300000002
#               ]
#             ],
#             "type": "LineString"
#           },
#           "vector": -1.0
#         },
#         {
#           "Oid": 19287,
#           "fid": 2231,
#           "geometry": {
#             "coordinates": [
#               [
#                 106.8269355,
#                 -6.1850687999999945
#               ],
#               [
#                 106.8266561,
#                 -6.184989700000002
#               ],
#               [
#                 106.8265526,
#                 -6.184946099999996
#               ],
#               [
#                 106.8264656,
#                 -6.184893700000005
#               ],
#               [
#                 106.8263476,
#                 -6.184837699999998
#               ],
#               [
#                 106.826125,
#                 -6.184717700000001
#               ],
#               [
#                 106.825956,
#                 -6.1846164000000075
#               ],
#               [
#                 106.825881,
#                 -6.1845548
#               ],
#               [
#                 106.8258702,
#                 -6.184530999999996
#               ]
#             ],
#             "type": "LineString"
#           },
#           "vector": -1.0
#         },
#         {
#           "Oid": 19287,
#           "fid": 554,
#           "geometry": {
#             "coordinates": [
#               [
#                 106.828256,
#                 -6.185048100000004
#               ],
#               [
#                 106.8273633,
#                 -6.184783700000008
#               ]
#             ],
#             "type": "LineString"
#           },
#           "vector": -1.0
#         },
#         {
#           "Oid": 19287,
#           "fid": 6314,
#           "geometry": {
#             "coordinates": [
#               [
#                 106.8273633,
#                 -6.184783700000008
#               ],
#               [
#                 106.827376,
#                 -6.1847101000000055
#               ]
#             ],
#             "type": "LineString"
#           },
#           "vector": 1.0
#         },
#         {
#           "Oid": 19287,
#           "fid": 2632,
#           "geometry": {
#             "coordinates": [
#               [
#                 106.8270743,
#                 -6.184062799999996
#               ],
#               [
#                 106.8271004,
#                 -6.183767799999994
#               ],
#               [
#                 106.8271027,
#                 -6.183761299999992
#               ],
#               [
#                 106.8271066,
#                 -6.183756399999992
#               ]
#             ],
#             "type": "LineString"
#           },
#           "vector": 1.0
#         },
#         {
#           "Oid": 19287,
#           "fid": 2782,
#           "geometry": {
#             "coordinates": [
#               [
#                 106.8270743,
#                 -6.184062799999996
#               ],
#               [
#                 106.8272779,
#                 -6.184132200000002
#               ],
#               [
#                 106.8274959,
#                 -6.184169699999992
#               ]
#             ],
#             "type": "LineString"
#           },
#           "vector": 1.0
#         },
#         {
#           "Oid": 19287,
#           "fid": 2232,
#           "geometry": {
#             "coordinates": [
#               [
#                 106.8248786,
#                 -6.184305599999994
#               ],
#               [
#                 106.8249801,
#                 -6.1842662
#               ],
#               [
#                 106.8250728,
#                 -6.184229599999992
#               ],
#               [
#                 106.8252675,
#                 -6.184151599999998
#               ],
#               [
#                 106.82535770000001,
#                 -6.184104300000008
#               ],
#               [
#                 106.82548710000002,
#                 -6.184031500000007
#               ],
#               [
#                 106.8255769,
#                 -6.183991499999997
#               ],
#               [
#                 106.8256698,
#                 -6.183952199999996
#               ],
#               [
#                 106.8256992,
#                 -6.183942799999995
#               ],
#               [
#                 106.8257193,
#                 -6.1839402000000065
#               ],
#               [
#                 106.8258386,
#                 -6.183936800000003
#               ]
#             ],
#             "type": "LineString"
#           },
#           "vector": -1.0
#         },
#         {
#           "Oid": 19287,
#           "fid": 9470,
#           "geometry": {
#             "coordinates": [
#               [
#                 106.8258386,
#                 -6.183936800000003
#               ],
#               [
#                 106.8257869,
#                 -6.183794100000009
#               ],
#               [
#                 106.8257711,
#                 -6.183730099999995
#               ],
#               [
#                 106.8257661,
#                 -6.183671999999995
#               ],
#               [
#                 106.82575270000001,
#                 -6.183313100000005
#               ],
#               [
#                 106.82575310000001,
#                 -6.183149099999992
#               ]
#             ],
#             "type": "LineString"
#           },
#           "vector": 1.0
#         },
#         {
#           "Oid": 19287,
#           "fid": 555,
#           "geometry": {
#             "coordinates": [
#               [
#                 106.827376,
#                 -6.1847101000000055
#               ],
#               [
#                 106.8274959,
#                 -6.184169699999992
#               ],
#               [
#                 106.8274959,
#                 -6.184169699999992
#               ]
#             ],
#             "type": "LineString"
#           },
#           "vector": 1.0
#         },
#         {
#           "Oid": 19287,
#           "fid": 2230,
#           "geometry": {
#             "coordinates": [
#               [
#                 106.8281701,
#                 -6.185405199999995
#               ],
#               [
#                 106.8281355,
#                 -6.185391900000002
#               ],
#               [
#                 106.8279292,
#                 -6.185322100000007
#               ],
#               [
#                 106.8276322,
#                 -6.185247500000007
#               ],
#               [
#                 106.8275041,
#                 -6.185226799999993
#               ],
#               [
#                 106.8274109,
#                 -6.185210799999993
#               ],
#               [
#                 106.8272408,
#                 -6.1851683000000035
#               ],
#               [
#                 106.8270745,
#                 -6.185117700000003
#               ],
#               [
#                 106.8269355,
#                 -6.1850687999999945
#               ],
#               [
#                 106.8269355,
#                 -6.1850687999999945
#               ]
#             ],
#             "type": "LineString"
#           },
#           "vector": -1.0
#         },
#         {
#           "Oid": 19287,
#           "fid": 6148,
#           "geometry": {
#             "coordinates": [
#               [
#                 106.8269355,
#                 -6.1850687999999945
#               ],
#               [
#                 106.8267781,
#                 -6.185497699999998
#               ],
#               [
#                 106.8267781,
#                 -6.185497699999998
#               ]
#             ],
#             "type": "LineString"
#           },
#           "vector": 1.0
#         },
#         {
#           "Oid": 19287,
#           "fid": 8367,
#           "geometry": {
#             "coordinates": [
#               [
#                 106.8271066,
#                 -6.183756399999992
#               ],
#               [
#                 106.8271196,
#                 -6.183753500000006
#               ],
#               [
#                 106.8272145,
#                 -6.183758499999993
#               ]
#             ],
#             "type": "LineString"
#           },
#           "vector": 1.0
#         },
#         {
#           "Oid": 19287,
#           "fid": 2780,
#           "geometry": {
#             "coordinates": [
#               [
#                 106.8272145,
#                 -6.183758499999993
#               ],
#               [
#                 106.8272278,
#                 -6.183759199999995
#               ],
#               [
#                 106.8272352,
#                 -6.183768200000005
#               ],
#               [
#                 106.8272379,
#                 -6.183779199999992
#               ],
#               [
#                 106.8272411,
#                 -6.18386180000001
#               ],
#               [
#                 106.8272433,
#                 -6.183867099999993
#               ],
#               [
#                 106.8272496,
#                 -6.1838712999999945
#               ],
#               [
#                 106.8273293,
#                 -6.183895200000008
#               ],
#               [
#                 106.8273351,
#                 -6.1838991999999955
#               ],
#               [
#                 106.8273375,
#                 -6.183906199999993
#               ],
#               [
#                 106.8273365,
#                 -6.1839282000000075
#               ],
#               [
#                 106.8273383,
#                 -6.183933299999995
#               ]
#             ],
#             "type": "LineString"
#           },
#           "vector": 1.0
#         },
#         {
#           "Oid": 19287,
#           "fid": 8366,
#           "geometry": {
#             "coordinates": [
#               [
#                 106.8275504,
#                 -6.183690800000006
#               ],
#               [
#                 106.8272828,
#                 -6.183688199999992
#               ],
#               [
#                 106.8272145,
#                 -6.183758499999993
#               ]
#             ],
#             "type": "LineString"
#           },
#           "vector": -1.0
#         },
#         {
#           "Oid": 19287,
#           "fid": 556,
#           "geometry": {
#             "coordinates": [
#               [
#                 106.8274959,
#                 -6.184169699999992
#               ],
#               [
#                 106.8275343,
#                 -6.1839744999999935
#               ],
#               [
#                 106.8275343,
#                 -6.1839744999999935
#               ]
#             ],
#             "type": "LineString"
#           },
#           "vector": 1.0
#         },
#         {
#           "Oid": 19287,
#           "fid": 2229,
#           "geometry": {
#             "coordinates": [
#               [
#                 106.8280069,
#                 -6.18589889999999
#               ],
#               [
#                 106.8279695,
#                 -6.185869100000006
#               ],
#               [
#                 106.8279262,
#                 -6.1858204999999975
#               ],
#               [
#                 106.8278652,
#                 -6.185755499999993
#               ],
#               [
#                 106.8278104,
#                 -6.185707099999991
#               ],
#               [
#                 106.8277896,
#                 -6.185689599999993
#               ],
#               [
#                 106.8277556,
#                 -6.185674800000004
#               ],
#               [
#                 106.8275282,
#                 -6.1856298999999915
#               ],
#               [
#                 106.8273392,
#                 -6.185602799999995
#               ],
#               [
#                 106.8272084,
#                 -6.185586500000005
#               ],
#               [
#                 106.8271055,
#                 -6.185569799999992
#               ],
#               [
#                 106.8269284,
#                 -6.1855335
#               ],
#               [
#                 106.8268627,
#                 -6.185520099999992
#               ],
#               [
#                 106.8267781,
#                 -6.185497699999998
#               ]
#             ],
#             "type": "LineString"
#           },
#           "vector": -1.0
#         },
#         {
#           "Oid": 19287,
#           "fid": 6149,
#           "geometry": {
#             "coordinates": [
#               [
#                 106.8267781,
#                 -6.185497699999998
#               ],
#               [
#                 106.8267095,
#                 -6.1857021
#               ],
#               [
#                 106.8267078,
#                 -6.1857225
#               ],
#               [
#                 106.8267129,
#                 -6.185734500000006
#               ],
#               [
#                 106.8267201,
#                 -6.185742799999996
#               ],
#               [
#                 106.8267337,
#                 -6.185753500000001
#               ]
#             ],
#             "type": "LineString"
#           },
#           "vector": 1.0
#         },
#         {
#           "Oid": 19287,
#           "fid": 557,
#           "geometry": {
#             "coordinates": [
#               [
#                 106.8275343,
#                 -6.1839744999999935
#               ],
#               [
#                 106.8275472,
#                 -6.1838631999999985
#               ],
#               [
#                 106.8275504,
#                 -6.183690800000006
#               ],
#               [
#                 106.8275504,
#                 -6.183690800000006
#               ]
#             ],
#             "type": "LineString"
#           },
#           "vector": 1.0
#         },
#         {
#           "Oid": 19287,
#           "fid": 6157,
#           "geometry": {
#             "coordinates": [
#               [
#                 106.8273383,
#                 -6.183933299999995
#               ],
#               [
#                 106.827344,
#                 -6.183936999999996
#               ],
#               [
#                 106.8275343,
#                 -6.1839744999999935
#               ]
#             ],
#             "type": "LineString"
#           },
#           "vector": -1.0
#         },
#         {
#           "Oid": 19287,
#           "fid": 558,
#           "geometry": {
#             "coordinates": [
#               [
#                 106.8275504,
#                 -6.183690800000006
#               ],
#               [
#                 106.8275598,
#                 -6.183174199999999
#               ]
#             ],
#             "type": "LineString"
#           },
#           "vector": 1.0
#         },
#         {
#           "Oid": 19287,
#           "fid": 78,
#           "geometry": {
#             "coordinates": [
#               [
#                 106.82575310000001,
#                 -6.183149099999992
#               ],
#               [
#                 106.8259182,
#                 -6.183138499999995
#               ],
#               [
#                 106.8259182,
#                 -6.183138499999995
#               ]
#             ],
#             "type": "LineString"
#           },
#           "vector": 1.0
#         },
#         {
#           "Oid": 19287,
#           "fid": 5724,
#           "geometry": {
#             "coordinates": [
#               [
#                 106.8256049,
#                 -6.183158600000006
#               ],
#               [
#                 106.82575310000001,
#                 -6.183149099999992
#               ]
#             ],
#             "type": "LineString"
#           },
#           "vector": -1.0
#         },
#         {
#           "Oid": 19287,
#           "fid": 2021,
#           "geometry": {
#             "coordinates": [
#               [
#                 106.8279688,
#                 -6.185982799999996
#               ],
#               [
#                 106.8278763,
#                 -6.185968099999999
#               ],
#               [
#                 106.8272117,
#                 -6.185878000000003
#               ],
#               [
#                 106.82698440000001,
#                 -6.1858241
#               ],
#               [
#                 106.8267337,
#                 -6.185753500000001
#               ]
#             ],
#             "type": "LineString"
#           },
#           "vector": -1.0
#         },
#         {
#           "Oid": 19287,
#           "fid": 8311,
#           "geometry": {
#             "coordinates": [
#               [
#                 106.8267337,
#                 -6.185753500000001
#               ],
#               [
#                 106.8266335,
#                 -6.185793799999992
#               ],
#               [
#                 106.8266129,
#                 -6.185802100000008
#               ],
#               [
#                 106.8266129,
#                 -6.185802100000008
#               ]
#             ],
#             "type": "LineString"
#           },
#           "vector": 1.0
#         },
#         {
#           "Oid": 19287,
#           "fid": 553,
#           "geometry": {
#             "coordinates": [
#               [
#                 106.8285111,
#                 -6.1851108999999935
#               ],
#               [
#                 106.828256,
#                 -6.185048100000004
#               ],
#               [
#                 106.828256,
#                 -6.185048100000004
#               ]
#             ],
#             "type": "LineString"
#           },
#           "vector": -1.0
#         },
#         {
#           "Oid": 19287,
#           "fid": 8379,
#           "geometry": {
#             "coordinates": [
#               [
#                 106.8282511,
#                 -6.185068699999994
#               ],
#               [
#                 106.828256,
#                 -6.185048100000004
#               ]
#             ],
#             "type": "LineString"
#           },
#           "vector": -1.0
#         },
#         {
#           "Oid": 19287,
#           "fid": 2228,
#           "geometry": {
#             "coordinates": [
#               [
#                 106.8281701,
#                 -6.185405199999995
#               ],
#               [
#                 106.8282511,
#                 -6.185068699999994
#               ]
#             ],
#             "type": "LineString"
#           },
#           "vector": -1.0
#         },
#         {
#           "Oid": 19287,
#           "fid": 4833,
#           "geometry": {
#             "coordinates": [
#               [
#                 106.8256049,
#                 -6.183158600000006
#               ],
#               [
#                 106.8255991,
#                 -6.183038200000007
#               ]
#             ],
#             "type": "LineString"
#           },
#           "vector": 1.0
#         },
#         {
#           "Oid": 19287,
#           "fid": 5723,
#           "geometry": {
#             "coordinates": [
#               [
#                 106.8254853,
#                 -6.183166300000006
#               ],
#               [
#                 106.8256049,
#                 -6.183158600000006
#               ],
#               [
#                 106.8256049,
#                 -6.183158600000006
#               ]
#             ],
#             "type": "LineString"
#           },
#           "vector": -1.0
#         },
#         {
#           "Oid": 19287,
#           "fid": 79,
#           "geometry": {
#             "coordinates": [
#               [
#                 106.8259182,
#                 -6.183138499999995
#               ],
#               [
#                 106.8259866,
#                 -6.183134200000005
#               ],
#               [
#                 106.8259866,
#                 -6.183134200000005
#               ]
#             ],
#             "type": "LineString"
#           },
#           "vector": 1.0
#         },
#         {
#           "Oid": 19287,
#           "fid": 8213,
#           "geometry": {
#             "coordinates": [
#               [
#                 106.8259182,
#                 -6.183138499999995
#               ],
#               [
#                 106.8259214,
#                 -6.1832715000000045
#               ]
#             ],
#             "type": "LineString"
#           },
#           "vector": 1.0
#         },
#         {
#           "Oid": 19287,
#           "fid": 8312,
#           "geometry": {
#             "coordinates": [
#               [
#                 106.8266129,
#                 -6.185802100000008
#               ],
#               [
#                 106.82652710000002,
#                 -6.186420799999991
#               ]
#             ],
#             "type": "LineString"
#           },
#           "vector": 1.0
#         },
#         {
#           "Oid": 19287,
#           "fid": 9059,
#           "geometry": {
#             "coordinates": [
#               [
#                 106.8256889,
#                 -6.185547099999993
#               ],
#               [
#                 106.8260481,
#                 -6.185632199999995
#               ],
#               [
#                 106.8263887,
#                 -6.1857639999999945
#               ],
#               [
#                 106.8264937,
#                 -6.185787299999996
#               ],
#               [
#                 106.8266129,
#                 -6.185802100000008
#               ]
#             ],
#             "type": "LineString"
#           },
#           "vector": -1.0
#         },
#         {
#           "Oid": 19287,
#           "fid": 80,
#           "geometry": {
#             "coordinates": [
#               [
#                 106.8259866,
#                 -6.183134200000005
#               ],
#               [
#                 106.8261055,
#                 -6.183126500000004
#               ],
#               [
#                 106.8261055,
#                 -6.183126500000004
#               ]
#             ],
#             "type": "LineString"
#           },
#           "vector": 1.0
#         },
#         {
#           "Oid": 19287,
#           "fid": 9284,
#           "geometry": {
#             "coordinates": [
#               [
#                 106.825984,
#                 -6.182995500000003
#               ],
#               [
#                 106.8259866,
#                 -6.183134200000005
#               ]
#             ],
#             "type": "LineString"
#           },
#           "vector": -1.0
#         },
#         {
#           "Oid": 19287,
#           "fid": 2650,
#           "geometry": {
#             "coordinates": [
#               [
#                 106.8250256,
#                 -6.185265700000002
#               ],
#               [
#                 106.8248786,
#                 -6.184305599999994
#               ],
#               [
#                 106.8248786,
#                 -6.184305599999994
#               ]
#             ],
#             "type": "LineString"
#           },
#           "vector": -1.0
#         },
#         {
#           "Oid": 19287,
#           "fid": 2651,
#           "geometry": {
#             "coordinates": [
#               [
#                 106.8248786,
#                 -6.184305599999994
#               ],
#               [
#                 106.8247393,
#                 -6.183214100000007
#               ]
#             ],
#             "type": "LineString"
#           },
#           "vector": 1.0
#         },
#         {
#           "Oid": 19287,
#           "fid": 5722,
#           "geometry": {
#             "coordinates": [
#               [
#                 106.8252968,
#                 -6.183178400000007
#               ],
#               [
#                 106.8253715,
#                 -6.183173599999998
#               ],
#               [
#                 106.8254853,
#                 -6.183166300000006
#               ],
#               [
#                 106.8254853,
#                 -6.183166300000006
#               ]
#             ],
#             "type": "LineString"
#           },
#           "vector": -1.0
#         },
#         {
#           "Oid": 19287,
#           "fid": 9287,
#           "geometry": {
#             "coordinates": [
#               [
#                 106.825477,
#                 -6.183012900000001
#               ],
#               [
#                 106.8254853,
#                 -6.183166300000006
#               ]
#             ],
#             "type": "LineString"
#           },
#           "vector": -1.0
#         },
#         {
#           "Oid": 19287,
#           "fid": 6601,
#           "geometry": {
#             "coordinates": [
#               [
#                 106.8255991,
#                 -6.183038200000007
#               ],
#               [
#                 106.8256037,
#                 -6.182743500000006
#               ],
#               [
#                 106.8256037,
#                 -6.182743500000006
#               ]
#             ],
#             "type": "LineString"
#           },
#           "vector": 1.0
#         },
#         {
#           "Oid": 19287,
#           "fid": 9285,
#           "geometry": {
#             "coordinates": [
#               [
#                 106.8259214,
#                 -6.1832715000000045
#               ],
#               [
#                 106.8259236,
#                 -6.183380799999999
#               ]
#             ],
#             "type": "LineString"
#           },
#           "vector": 1.0
#         },
#         {
#           "Oid": 19287,
#           "fid": 81,
#           "geometry": {
#             "coordinates": [
#               [
#                 106.8261055,
#                 -6.183126500000004
#               ],
#               [
#                 106.8261977,
#                 -6.183120600000003
#               ],
#               [
#                 106.8261977,
#                 -6.183120600000003
#               ]
#             ],
#             "type": "LineString"
#           },
#           "vector": 1.0
#         },
#         {
#           "Oid": 19287,
#           "fid": 9282,
#           "geometry": {
#             "coordinates": [
#               [
#                 106.8261055,
#                 -6.183126500000004
#               ],
#               [
#                 106.8261153,
#                 -6.183224300000006
#               ]
#             ],
#             "type": "LineString"
#           },
#           "vector": 1.0
#         },
#         {
#           "Oid": 19287,
#           "fid": 552,
#           "geometry": {
#             "coordinates": [
#               [
#                 106.8286064,
#                 -6.185144899999994
#               ],
#               [
#                 106.8285111,
#                 -6.1851108999999935
#               ],
#               [
#                 106.8285111,
#                 -6.1851108999999935
#               ]
#             ],
#             "type": "LineString"
#           },
#           "vector": -1.0
#         },
#         {
#           "Oid": 19287,
#           "fid": 8378,
#           "geometry": {
#             "coordinates": [
#               [
#                 106.8285141,
#                 -6.1850999
#               ],
#               [
#                 106.8285111,
#                 -6.1851108999999935
#               ]
#             ],
#             "type": "LineString"
#           },
#           "vector": -1.0
#         },
#         {
#           "Oid": 19287,
#           "fid": 8177,
#           "geometry": {
#             "coordinates": [
#               [
#                 106.8261838,
#                 -6.182980899999998
#               ],
#               [
#                 106.82616900000001,
#                 -6.182902200000006
#               ],
#               [
#                 106.8260121,
#                 -6.182910199999997
#               ],
#               [
#                 106.825984,
#                 -6.182995500000003
#               ]
#             ],
#             "type": "LineString"
#           },
#           "vector": -1.0
#         },
#         {
#           "Oid": 19287,
#           "fid": 2778,
#           "geometry": {
#             "coordinates": [
#               [
#                 106.8293765,
#                 -6.184759299999997
#               ],
#               [
#                 106.8289679,
#                 -6.1846495000000035
#               ],
#               [
#                 106.828927,
#                 -6.184642800000008
#               ],
#               [
#                 106.8288794,
#                 -6.184641499999994
#               ],
#               [
#                 106.8286656,
#                 -6.184575099999993
#               ],
#               [
#                 106.8286594,
#                 -6.1845746000000075
#               ],
#               [
#                 106.8286528,
#                 -6.184575799999999
#               ],
#               [
#                 106.8286464,
#                 -6.184579199999992
#               ],
#               [
#                 106.8286411,
#                 -6.184585699999995
#               ],
#               [
#                 106.8285885,
#                 -6.184822799999992
#               ],
#               [
#                 106.8285141,
#                 -6.1850999
#               ]
#             ],
#             "type": "LineString"
#           },
#           "vector": -1.0
#         },
#         {
#           "Oid": 19287,
#           "fid": 8198,
#           "geometry": {
#             "coordinates": [
#               [
#                 106.8252932,
#                 -6.1829257999999925
#               ],
#               [
#                 106.825465,
#                 -6.182918199999996
#               ],
#               [
#                 106.8254704,
#                 -6.182961199999993
#               ],
#               [
#                 106.825477,
#                 -6.183012900000001
#               ]
#             ],
#             "type": "LineString"
#           },
#           "vector": -1.0
#         },
#         {
#           "Oid": 19287,
#           "fid": 82,
#           "geometry": {
#             "coordinates": [
#               [
#                 106.8261977,
#                 -6.183120600000003
#               ],
#               [
#                 106.8262672,
#                 -6.183116200000004
#               ],
#               [
#                 106.8262672,
#                 -6.183116200000004
#               ]
#             ],
#             "type": "LineString"
#           },
#           "vector": 1.0
#         },
#         {
#           "Oid": 19287,
#           "fid": 9283,
#           "geometry": {
#             "coordinates": [
#               [
#                 106.8261977,
#                 -6.183120600000003
#               ],
#               [
#                 106.8261838,
#                 -6.182980899999998
#               ]
#             ],
#             "type": "LineString"
#           },
#           "vector": 1.0
#         },
#         {
#           "Oid": 19287,
#           "fid": 8215,
#           "geometry": {
#             "coordinates": [
#               [
#                 106.8261153,
#                 -6.183224300000006
#               ],
#               [
#                 106.8261234,
#                 -6.183303500000004
#               ],
#               [
#                 106.8261234,
#                 -6.183303500000004
#               ]
#             ],
#             "type": "LineString"
#           },
#           "vector": 1.0
#         },
#         {
#           "Oid": 19287,
#           "fid": 5721,
#           "geometry": {
#             "coordinates": [
#               [
#                 106.8247393,
#                 -6.183214100000007
#               ],
#               [
#                 106.8252968,
#                 -6.183178400000007
#               ],
#               [
#                 106.8252968,
#                 -6.183178400000007
#               ]
#             ],
#             "type": "LineString"
#           },
#           "vector": -1.0
#         },
#         {
#           "Oid": 19287,
#           "fid": 9286,
#           "geometry": {
#             "coordinates": [
#               [
#                 106.8252968,
#                 -6.183178400000007
#               ],
#               [
#                 106.8252933,
#                 -6.183031500000005
#               ]
#             ],
#             "type": "LineString"
#           },
#           "vector": 1.0
#         },
#         {
#           "Oid": 19287,
#           "fid": 551,
#           "geometry": {
#             "coordinates": [
#               [
#                 106.8292181,
#                 -6.185345700000005
#               ],
#               [
#                 106.8286064,
#                 -6.185144899999994
#               ],
#               [
#                 106.8286064,
#                 -6.185144899999994
#               ]
#             ],
#             "type": "LineString"
#           },
#           "vector": -1.0
#         },
#         {
#           "Oid": 19287,
#           "fid": 2224,
#           "geometry": {
#             "coordinates": [
#               [
#                 106.8284958,
#                 -6.185587799999997
#               ],
#               [
#                 106.8285198,
#                 -6.185510100000007
#               ],
#               [
#                 106.8286064,
#                 -6.185144899999994
#               ]
#             ],
#             "type": "LineString"
#           },
#           "vector": -1.0
#         },
#         {
#           "Oid": 19287,
#           "fid": 2227,
#           "geometry": {
#             "coordinates": [
#               [
#                 106.8281369,
#                 -6.185473199999995
#               ],
#               [
#                 106.8281523,
#                 -6.185444599999997
#               ],
#               [
#                 106.8281701,
#                 -6.185405199999995
#               ],
#               [
#                 106.8281701,
#                 -6.185405199999995
#               ]
#             ],
#             "type": "LineString"
#           },
#           "vector": -1.0
#         },
#         {
#           "Oid": 19287,
#           "fid": 6313,
#           "geometry": {
#             "coordinates": [
#               [
#                 106.8275598,
#                 -6.183174199999999
#               ],
#               [
#                 106.8275745,
#                 -6.1830323999999965
#               ]
#             ],
#             "type": "LineString"
#           },
#           "vector": 1.0
#         },
#         {
#           "Oid": 19287,
#           "fid": 83,
#           "geometry": {
#             "coordinates": [
#               [
#                 106.8262672,
#                 -6.183116200000004
#               ],
#               [
#                 106.8263699,
#                 -6.183109600000002
#               ],
#               [
#                 106.8263699,
#                 -6.183109600000002
#               ]
#             ],
#             "type": "LineString"
#           },
#           "vector": 1.0
#         },
#         {
#           "Oid": 19287,
#           "fid": 9281,
#           "geometry": {
#             "coordinates": [
#               [
#                 106.8262669,
#                 -6.182999599999992
#               ],
#               [
#                 106.8262672,
#                 -6.183116200000004
#               ]
#             ],
#             "type": "LineString"
#           },
#           "vector": -1.0
#         },
#         {
#           "Oid": 19287,
#           "fid": 8214,
#           "geometry": {
#             "coordinates": [
#               [
#                 106.8261234,
#                 -6.183303500000004
#               ],
#               [
#                 106.8262884,
#                 -6.183299499999998
#               ]
#             ],
#             "type": "LineString"
#           },
#           "vector": 1.0
#         },
#         {
#           "Oid": 19287,
#           "fid": 8216,
#           "geometry": {
#             "coordinates": [
#               [
#                 106.8261234,
#                 -6.183303500000004
#               ],
#               [
#                 106.8261369,
#                 -6.1837168000000045
#               ]
#             ],
#             "type": "LineString"
#           },
#           "vector": 1.0
#         },
#         {
#           "Oid": 19287,
#           "fid": 2226,
#           "geometry": {
#             "coordinates": [
#               [
#                 106.8280069,
#                 -6.18589889999999
#               ],
#               [
#                 106.8280324,
#                 -6.185811099999998
#               ],
#               [
#                 106.8280586,
#                 -6.185681000000002
#               ],
#               [
#                 106.8281369,
#                 -6.185473199999995
#               ],
#               [
#                 106.8281369,
#                 -6.185473199999995
#               ]
#             ],
#             "type": "LineString"
#           },
#           "vector": -1.0
#         },
#         {
#           "Oid": 19287,
#           "fid": 8368,
#           "geometry": {
#             "coordinates": [
#               [
#                 106.8281369,
#                 -6.185473199999995
#               ],
#               [
#                 106.8282102,
#                 -6.185498799999994
#               ],
#               [
#                 106.8284958,
#                 -6.185587799999997
#               ]
#             ],
#             "type": "LineString"
#           },
#           "vector": 1.0
#         },
#         {
#           "Oid": 19287,
#           "fid": 6602,
#           "geometry": {
#             "coordinates": [
#               [
#                 106.8256037,
#                 -6.182743500000006
#               ],
#               [
#                 106.82561250000002,
#                 -6.182174199999993
#               ]
#             ],
#             "type": "LineString"
#           },
#           "vector": 1.0
#         },
#         {
#           "Oid": 19287,
#           "fid": 8197,
#           "geometry": {
#             "coordinates": [
#               [
#                 106.8256037,
#                 -6.182743500000006
#               ],
#               [
#                 106.82583910000001,
#                 -6.1827341999999925
#               ]
#             ],
#             "type": "LineString"
#           },
#           "vector": 1.0
#         },
#         {
#           "Oid": 19287,
#           "fid": 8199,
#           "geometry": {
#             "coordinates": [
#               [
#                 106.8252933,
#                 -6.183031500000005
#               ],
#               [
#                 106.82529060000002,
#                 -6.182991499999998
#               ],
#               [
#                 106.8252932,
#                 -6.1829257999999925
#               ],
#               [
#                 106.8252932,
#                 -6.1829257999999925
#               ]
#             ],
#             "type": "LineString"
#           },
#           "vector": 1.0
#         },
#         {
#           "Oid": 19287,
#           "fid": 84,
#           "geometry": {
#             "coordinates": [
#               [
#                 106.8263699,
#                 -6.183109600000002
#               ],
#               [
#                 106.8264592,
#                 -6.183103900000003
#               ],
#               [
#                 106.8264592,
#                 -6.183103900000003
#               ]
#             ],
#             "type": "LineString"
#           },
#           "vector": 1.0
#         },
#         {
#           "Oid": 19287,
#           "fid": 9278,
#           "geometry": {
#             "coordinates": [
#               [
#                 106.8263899,
#                 -6.183230899999997
#               ],
#               [
#                 106.8263699,
#                 -6.183109600000002
#               ]
#             ],
#             "type": "LineString"
#           },
#           "vector": -1.0
#         },
#         {
#           "Oid": 19287,
#           "fid": 93,
#           "geometry": {
#             "coordinates": [
#               [
#                 106.8274218,
#                 -6.183042199999996
#               ],
#               [
#                 106.8275745,
#                 -6.1830323999999965
#               ],
#               [
#                 106.8275745,
#                 -6.1830323999999965
#               ]
#             ],
#             "type": "LineString"
#           },
#           "vector": -1.0
#         },
#         {
#           "Oid": 19287,
#           "fid": 94,
#           "geometry": {
#             "coordinates": [
#               [
#                 106.8275745,
#                 -6.1830323999999965
#               ],
#               [
#                 106.82771660000002,
#                 -6.183023299999995
#               ],
#               [
#                 106.82771660000002,
#                 -6.183023299999995
#               ]
#             ],
#             "type": "LineString"
#           },
#           "vector": 1.0
#         },
#         {
#           "Oid": 19287,
#           "fid": 8182,
#           "geometry": {
#             "coordinates": [
#               [
#                 106.8262669,
#                 -6.182911499999994
#               ],
#               [
#                 106.8262669,
# ...
#           "JunctCnt": 2,
#           "coords": [
#             106.82626664903029,
#             -6.1830017316667325,
#             2
#           ],
#           "fid": 7096,
#           "geometry": {
#             "coordinates": [
#               106.82626664903029,
#               -6.1830017316667325
#             ],
#             "type": "Point"
#           }
#         },
#         {
#           "Distance": "338.2",
#           "JunctCnt": 2,
#           "coords": [
#             106.82692261391236,
#             -6.182954268045479,
#             2
#           ],
#           "fid": 7097,
#           "geometry": {
#             "coordinates": [
#               106.82692261391236,
#               -6.182954268045479
#             ],
#             "type": "Point"
#           }
#         },
#         {
#           "Distance": "298.4",
#           "JunctCnt": 2,
#           "coords": [
#             106.82656525434597,
#             -6.182973580068401,
#             2
#           ],
#           "fid": 7098,
#           "geometry": {
#             "coordinates": [
#               106.82656525434597,
#               -6.182973580068401
#             ],
#             "type": "Point"
#           }
#         },
#         {
#           "Distance": "306.0",
#           "JunctCnt": 2,
#           "coords": [
#             106.82729914033487,
#             -6.182925848141246,
#             2
#           ],
#           "fid": 7099,
#           "geometry": {
#             "coordinates": [
#               106.82729914033487,
#               -6.182925848141246
#             ],
#             "type": "Point"
#           }
#         },
#         {
#           "Distance": "339.3",
#           "JunctCnt": 2,
#           "coords": [
#             106.82700671528482,
#             -6.182944937146295,
#             2
#           ],
#           "fid": 7100,
#           "geometry": {
#             "coordinates": [
#               106.82700671528482,
#               -6.182944937146295
#             ],
#             "type": "Point"
#           }
#         },
#         {
#           "Distance": "282.7",
#           "JunctCnt": 1,
#           "coords": [
#             106.82583884506887,
#             -6.182731949539409,
#             2
#           ],
#           "fid": 7113,
#           "geometry": {
#             "coordinates": [
#               106.82583884506887,
#               -6.182731949539409
#             ],
#             "type": "Point"
#           }
#         },
#         {
#           "Distance": "270.6",
#           "JunctCnt": 3,
#           "coords": [
#             106.82529291769785,
#             -6.182923701738306,
#             2
#           ],
#           "fid": 7114,
#           "geometry": {
#             "coordinates": [
#               106.82529291769785,
#               -6.182923701738306
#             ],
#             "type": "Point"
#           }
#         },
#         {
#           "Distance": "241.0",
#           "JunctCnt": 2,
#           "coords": [
#             106.82547673826272,
#             -6.183013487718454,
#             2
#           ],
#           "fid": 7115,
#           "geometry": {
#             "coordinates": [
#               106.82547673826272,
#               -6.183013487718454
#             ],
#             "type": "Point"
#           }
#         },
#         {
#           "Distance": "261.2",
#           "JunctCnt": 2,
#           "coords": [
#             106.82529328980704,
#             -6.183032201412562,
#             2
#           ],
#           "fid": 7116,
#           "geometry": {
#             "coordinates": [
#               106.82529328980704,
#               -6.183032201412562
#             ],
#             "type": "Point"
#           }
#         },
#         {
#           "Distance": "290.0",
#           "JunctCnt": 1,
#           "coords": [
#             106.82530023360167,
#             -6.182751883432578,
#             2
#           ],
#           "fid": 7117,
#           "geometry": {
#             "coordinates": [
#               106.82530023360167,
#               -6.182751883432578
#             ],
#             "type": "Point"
#           }
#         },
#         {
#           "Distance": "376.6",
#           "JunctCnt": 2,
#           "coords": [
#             106.82797070023241,
#             -6.1836378351961026,
#             2
#           ],
#           "fid": 7123,
#           "geometry": {
#             "coordinates": [
#               106.82797070023241,
#               -6.1836378351961026
#             ],
#             "type": "Point"
#           }
#         },
#         {
#           "Distance": "227.3",
#           "JunctCnt": 2,
#           "coords": [
#             106.82592145080532,
#             -6.183274170274458,
#             2
#           ],
#           "fid": 7130,
#           "geometry": {
#             "coordinates": [
#               106.82592145080532,
#               -6.183274170274458
#             ],
#             "type": "Point"
#           }
#         },
#         {
#           "Distance": "253.1",
#           "JunctCnt": 3,
#           "coords": [
#             106.8261231231041,
#             -6.183300602422677,
#             2
#           ],
#           "fid": 7131,
#           "geometry": {
#             "coordinates": [
#               106.8261231231041,
#               -6.183300602422677
#             ],
#             "type": "Point"
#           }
#         },
#         {
#           "Distance": "271.3",
#           "JunctCnt": 1,
#           "coords": [
#             106.8262885648678,
#             -6.183300033797486,
#             2
#           ],
#           "fid": 7132,
#           "geometry": {
#             "coordinates": [
#               106.8262885648678,
#               -6.183300033797486
#             ],
#             "type": "Point"
#           }
#         },
#         {
#           "Distance": "244.3",
#           "JunctCnt": 2,
#           "coords": [
#             106.82611553448804,
#             -6.183228294568516,
#             2
#           ],
#           "fid": 7133,
#           "geometry": {
#             "coordinates": [
#               106.82611553448804,
#               -6.183228294568516
#             ],
#             "type": "Point"
#           }
#         },
#         {
#           "Distance": "298.8",
#           "JunctCnt": 1,
#           "coords": [
#             106.82613697255375,
#             -6.183716474942373,
#             2
#           ],
#           "fid": 7134,
#           "geometry": {
#             "coordinates": [
#               106.82613697255375,
#               -6.183716474942373
#             ],
#             "type": "Point"
#           }
#         },
#         {
#           "Distance": "301.0",
#           "JunctCnt": 2,
#           "coords": [
#             106.82660731145505,
#             -6.183217562461632,
#             2
#           ],
#           "fid": 7135,
#           "geometry": {
#             "coordinates": [
#               106.82660731145505,
#               -6.183217562461632
#             ],
#             "type": "Point"
#           }
#         },
#         {
#           "Distance": "309.1",
#           "JunctCnt": 3,
#           "coords": [
#             106.82661264154524,
#             -6.183289878053667,
#             2
#           ],
#           "fid": 7136,
#           "geometry": {
#             "coordinates": [
#               106.82661264154524,
#               -6.183289878053667
#             ],
#             "type": "Point"
#           }
#         },
#         {
#           "Distance": "352.7",
#           "JunctCnt": 1,
#           "coords": [
#             106.82665579099285,
#             -6.1836875662363,
#             2
#           ],
#           "fid": 7137,
#           "geometry": {
#             "coordinates": [
#               106.82665579099285,
#               -6.1836875662363
#             ],
#             "type": "Point"
#           }
#         },
#         {
#           "Distance": "315.6",
#           "JunctCnt": 2,
#           "coords": [
#             106.826685419005,
#             -6.183271544378281,
#             2
#           ],
#           "fid": 7138,
#           "geometry": {
#             "coordinates": [
#               106.826685419005,
#               -6.183271544378281
#             ],
#             "type": "Point"
#           }
#         },
#         {
#           "Distance": "330.1",
#           "JunctCnt": 2,
#           "coords": [
#             106.82682595414765,
#             -6.183252977737384,
#             2
#           ],
#           "fid": 7139,
#           "geometry": {
#             "coordinates": [
#               106.82682595414765,
#               -6.183252977737384
#             ],
#             "type": "Point"
#           }
#         },
#         {
#           "Distance": "384.0",
#           "JunctCnt": 1,
#           "coords": [
#             106.82689752236861,
#             -6.1837048185675805,
#             2
#           ],
#           "fid": 7140,
#           "geometry": {
#             "coordinates": [
#               106.82689752236861,
#               -6.1837048185675805
#             ],
#             "type": "Point"
#           }
#         },
#         {
#           "Distance": "316.2",
#           "JunctCnt": 1,
#           "coords": [
#             106.82734546073495,
#             -6.1832602330760835,
#             2
#           ],
#           "fid": 7141,
#           "geometry": {
#             "coordinates": [
#               106.82734546073495,
#               -6.1832602330760835
#             ],
#             "type": "Point"
#           }
#         },
#         {
#           "Distance": "298.7",
#           "JunctCnt": 2,
#           "coords": [
#             106.82732178243921,
#             -6.18310660499744,
#             2
#           ],
#           "fid": 7142,
#           "geometry": {
#             "coordinates": [
#               106.82732178243921,
#               -6.18310660499744
#             ],
#             "type": "Point"
#           }
#         },
#         {
#           "Distance": "388.6",
#           "JunctCnt": 2,
#           "coords": [
#             106.828613725595,
#             -6.183111202155516,
#             2
#           ],
#           "fid": 7152,
#           "geometry": {
#             "coordinates": [
#               106.828613725595,
#               -6.183111202155516
#             ],
#             "type": "Point"
#           }
#         },
#         {
#           "Distance": "378.7",
#           "JunctCnt": 1,
#           "coords": [
#             106.82457154657958,
#             -6.185304159276437,
#             2
#           ],
#           "fid": 7176,
#           "geometry": {
#             "coordinates": [
#               106.82457154657958,
#               -6.185304159276437
#             ],
#             "type": "Point"
#           }
#         },
#         {
#           "Distance": "213.1",
#           "JunctCnt": 3,
#           "coords": [
#             106.82661280077797,
#             -6.185803480957728,
#             2
#           ],
#           "fid": 7193,
#           "geometry": {
#             "coordinates": [
#               106.82661280077797,
#               -6.185803480957728
#             ],
#             "type": "Point"
#           }
#         },
#         {
#           "Distance": "282.2",
#           "JunctCnt": 1,
#           "coords": [
#             106.8265268264668,
#             -6.186418614879911,
#             2
#           ],
#           "fid": 7194,
#           "geometry": {
#             "coordinates": [
#               106.8265268264668,
#               -6.186418614879911
#             ],
#             "type": "Point"
#           }
#         },
#         {
#           "Distance": "308.6",
#           "JunctCnt": 2,
#           "coords": [
#             106.82785998420285,
#             -6.1831318790452965,
#             2
#           ],
#           "fid": 7277,
#           "geometry": {
#             "coordinates": [
#               106.82785998420285,
#               -6.1831318790452965
#             ],
#             "type": "Point"
#           }
#         },
#         {
#           "Distance": "352.2",
#           "JunctCnt": 1,
#           "coords": [
#             106.82822151949306,
#             -6.185806987632035,
#             2
#           ],
#           "fid": 7443,
#           "geometry": {
#             "coordinates": [
#               106.82822151949306,
#               -6.185806987632035
#             ],
#             "type": "Point"
#           }
#         },
#         {
#           "Distance": "327.6",
#           "JunctCnt": 1,
#           "coords": [
#             106.82643049645596,
#             -6.183688340767048,
#             2
#           ],
#           "fid": 7521,
#           "geometry": {
#             "coordinates": [
#               106.82643049645596,
#               -6.183688340767048
#             ],
#             "type": "Point"
#           }
#         },
#         {
#           "Distance": "285.8",
#           "JunctCnt": 3,
#           "coords": [
#             106.82640381504007,
#             -6.183317721131814,
#             2
#           ],
#           "fid": 7522,
#           "geometry": {
#             "coordinates": [
#               106.82640381504007,
#               -6.183317721131814
#             ],
#             "type": "Point"
#           }
#         },
#         {
#           "Distance": "276.3",
#           "JunctCnt": 2,
#           "coords": [
#             106.82638995320511,
#             -6.183227351374964,
#             2
#           ],
#           "fid": 7523,
#           "geometry": {
#             "coordinates": [
#               106.82638995320511,
#               -6.183227351374964
#             ],
#             "type": "Point"
#           }
#         },
#         {
#           "Distance": "319.6",
#           "JunctCnt": 3,
#           "coords": [
#             106.82568869763051,
#             -6.185544447726402,
#             2
#           ],
#           "fid": 7579,
#           "geometry": {
#             "coordinates": [
#               106.82568869763051,
#               -6.185544447726402
#             ],
#             "type": "Point"
#           }
#         },
#         {
#           "Distance": "349.5",
#           "JunctCnt": 1,
#           "coords": [
#             106.82671241695799,
#             -6.18356982894455,
#             2
#           ],
#           "fid": 7623,
#           "geometry": {
#             "coordinates": [
#               106.82671241695799,
#               -6.18356982894455
#             ],
#             "type": "Point"
#           }
#         },
#         {
#           "Distance": "239.4",
#           "JunctCnt": 1,
#           "coords": [
#             106.82592351700738,
#             -6.183382664087821,
#             2
#           ],
#           "fid": 7624,
#           "geometry": {
#             "coordinates": [
#               106.82592351700738,
#               -6.183382664087821
#             ],
#             "type": "Point"
#           }
#         },
#         {
#           "Distance": "381.7",
#           "JunctCnt": 2,
#           "coords": [
#             106.82412941298772,
#             -6.183325534280404,
#             2
#           ],
#           "fid": 7629,
#           "geometry": {
#             "coordinates": [
#               106.82412941298772,
#               -6.183325534280404
#             ],
#             "type": "Point"
#           }
#         },
#         {
#           "Distance": "373.8",
#           "JunctCnt": 3,
#           "coords": [
#             106.82461428662917,
#             -6.182618612979436,
#             2
#           ],
#           "fid": 7679,
#           "geometry": {
#             "coordinates": [
#               106.82461428662917,
#               -6.182618612979436
#             ],
#             "type": "Point"
#           }
#         }
#       ],
#       "getAlignmentBaseline": "center",
#       "getBackgroundColor": [
#         255,
#         255,
#         255,
#         180
#       ],
#       "getColor": [
#         0,
#         0,
#         0
#       ],
#       "getPosition": "@@=coords",
#       "getSize": 8,
#       "getText": "@@=Distance",
#       "getTextAnchor": "middle",
#       "id": "fff2648e-bf1c-4c7b-9fb7-2e60e6fde16c",
#       "pickable": false
#     },
#     {
#       "@@type": "GeoJsonLayer",
#       "data": [
#         {
#           "Area_Sqm": 215,
#           "Function": "Residential",
#           "fid": 19287,
#           "geometry": {
#             "coordinates": [
#               106.82649013011793,
#               -6.184588108600299
#             ],
#             "type": "Point"
#           },
#           "wadmkc": "Menteng",
#           "wadmkk": "Jakarta Pusat",
#           "xLn_ID": 5866,
#           "xPt_X": 702104.962390863,
#           "xPt_Y": 9316060.463981386
#         }
#       ],
#       "getFillColor": [
#         255,
#         80,
#         80
#       ],
#       "getLineWidth": 0,
#       "getRadius": 4,
#       "id": "8c69f2c7-3674-4f04-bd66-db5eb6b360ad",
#       "pickable": true
#     }
#   ],
#   "mapProvider": "carto",
#   "mapStyle": "https://basemaps.cartocdn.com/gl/positron-gl-style/style.json",
#   "views": [
#     {
#       "@@type": "MapView",
#       "controller": true
#     }
#   ]
# }

# %% [markdown]
# #### 3. Interactive distance
# pydeck output can be used to make interactive display! Utilizing ipywidget slider for distance.

# %%
from IPython.display import display
import ipywidgets as widgets
a = widgets.FloatSlider(
    value=7.5,
    min=200,
    max=2000.0,
    step=0.1,
    description='Distance:',
    disabled=False,
    continuous_update=True,
    orientation='horizontal',
    readout=True,
    readout_format='.1f',
    width='500px',
)

rslt = nwSim.PathReach(OriginId, a.value, True, True, True, True)
ddeck = rslt[0]

output = widgets.Output()

def valcg(change):
    with output:
        output.clear_output(wait=True)
        rsltB = nwSim.PathReach(OriginId, a.value, True, True, True, True, True)
        ddeck.layers = rsltB
        display(ddeck)
with output:
    display(ddeck)
a.observe(valcg)
display(a, output)
# Out:
# to see map, please set/access index 0 of result
# FloatSlider(value=200.0, description='Distance:', max=2000.0, min=200.0, readout_format='.1f')
# Output()
